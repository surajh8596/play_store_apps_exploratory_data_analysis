# %%
import pandas as pd
import math
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('D:\\PGP IN DATA SCIENCE with Careerera\\Files\\app.csv')

# %%
df.head(5)
# Out:
#    id                     app_name   genre  rating           reviews  \
# 0   2  Sonic the Hedgehog™ Classic     NaN     4.1     193,898 total
# 1   3                  Push'em all  Action     3.8     119,679 total
# 2   5              Sky Fighters 3D  Action     4.2     196,685 total
# 3   6                  Robbery Bob  Action     4.3     984,779 total
# 4   7               Shadow Fight 2  Action     4.6  12,861,970 total
#
#   cost_label  rate_5_pc  rate_4_pc  rate_3_pc  rate_2_pc  rate_1_pc  \
# 0    Install    68.0272   10.20410    5.44218   3.401360   12.92520
# 1    Install    56.1798   12.92130    8.42697   5.056180   17.41570
# 2    Install    67.1141   11.40940    7.38255   3.355700   10.73830
# 3    Install    74.0741    8.14815    5.18518   2.962960    9.62963
# 4    Install    85.4701    5.98291    2.56410   0.854701    5.12821
#
#           updated  size      installs current_version requires_android  \
# 0  March 24, 2020   61M   10,000,000+           3.5.1       4.4 and up
# 1  April 16, 2020   41M   10,000,000+            1.14       4.4 and up
# 2    May 14, 2019   19M   10,000,000+             1.5       4.0 and up
# 3  March 25, 2020   42M   50,000,000+         1.18.23       4.1 and up
# 4  April 15, 2020  142M  100,000,000+           2.5.1       4.1 and up
#
#   content_rating                in_app_products          offered_by
# 0   Rated for 3+               ₫45,000 per item                SEGA
# 1   Rated for 3+               ₫92,000 per item              VOODOO
# 2   Rated for 7+  ₫42,000 - ₫2,100,000 per item  Doodle Mobile Ltd.
# 3   Rated for 7+    ₫18,000 - ₫192,000 per item      Level Eight AB
# 4  Rated for 12+   ₫6,000 - ₫1,149,999 per item               NEKKI

# %%
df.shape
# Out:
# (53732, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53732 entries, 0 to 53731
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                53732 non-null  int64
#  1   app_name          53675 non-null  object
#  2   genre             48654 non-null  object
#  3   rating            47688 non-null  float64
#  4   reviews           47688 non-null  object
#  5   cost_label        53653 non-null  object
#  6   rate_5_pc         47688 non-null  float64
#  7   rate_4_pc         47688 non-null  float64
#  8   rate_3_pc         47688 non-null  float64
#  9   rate_2_pc         47688 non-null  float64
#  10  rate_1_pc         47688 non-null  float64
#  11  updated           53675 non-null  object
#  12  size              53675 non-null  object
#  13  installs          53658 non-null  object
#  14  current_version   53660 non-null  object
#  15  requires_android  53643 non-null  object
#  16  content_rating    53675 non-null  object
#  17  in_app_products   24275 non-null  object
#  18  offered_by        53675 non-null  object
# dtypes: float64(6), int64(1), object(12)
# memory usage: 7.8+ MB

# %%
##convert object column to datetime and then extract year
df['updated']=pd.to_datetime(df.updated)

# %%
df['year']=df['updated'].dt.year

# %%
df.head(5)
# Out:
#    id                     app_name   genre  rating           reviews  \
# 0   2  Sonic the Hedgehog™ Classic     NaN     4.1     193,898 total
# 1   3                  Push'em all  Action     3.8     119,679 total
# 2   5              Sky Fighters 3D  Action     4.2     196,685 total
# 3   6                  Robbery Bob  Action     4.3     984,779 total
# 4   7               Shadow Fight 2  Action     4.6  12,861,970 total
#
#   cost_label  rate_5_pc  rate_4_pc  rate_3_pc  rate_2_pc  rate_1_pc  \
# 0    Install    68.0272   10.20410    5.44218   3.401360   12.92520
# 1    Install    56.1798   12.92130    8.42697   5.056180   17.41570
# 2    Install    67.1141   11.40940    7.38255   3.355700   10.73830
# 3    Install    74.0741    8.14815    5.18518   2.962960    9.62963
# 4    Install    85.4701    5.98291    2.56410   0.854701    5.12821
#
#      updated  size      installs current_version requires_android  \
# 0 2020-03-24   61M   10,000,000+           3.5.1       4.4 and up
# 1 2020-04-16   41M   10,000,000+            1.14       4.4 and up
# 2 2019-05-14   19M   10,000,000+             1.5       4.0 and up
# 3 2020-03-25   42M   50,000,000+         1.18.23       4.1 and up
# 4 2020-04-15  142M  100,000,000+           2.5.1       4.1 and up
#
#   content_rating                in_app_products          offered_by    year
# 0   Rated for 3+               ₫45,000 per item                SEGA  2020.0
# 1   Rated for 3+               ₫92,000 per item              VOODOO  2020.0
# 2   Rated for 7+  ₫42,000 - ₫2,100,000 per item  Doodle Mobile Ltd.  2019.0
# 3   Rated for 7+    ₫18,000 - ₫192,000 per item      Level Eight AB  2020.0
# 4  Rated for 12+   ₫6,000 - ₫1,149,999 per item               NEKKI  2020.0

# %%
## how many years of data
df.year.unique()
# Out:
# array([2020., 2019., 2018., 2017., 2016., 2015., 2013., 2014., 2012.,
#          nan, 2011., 2010.])

# %%
df.dropna(inplace=True)
df.drop('id', axis=1, inplace=True)

# %%
df.head(5)
# Out:
#                          app_name   genre  rating           reviews  \
# 1                     Push'em all  Action     3.8     119,679 total
# 2                 Sky Fighters 3D  Action     4.2     196,685 total
# 3                     Robbery Bob  Action     4.3     984,779 total
# 4                  Shadow Fight 2  Action     4.6  12,861,970 total
# 5  Cover Strike - 3D Team Shooter  Action     4.0      43,322 total
#
#   cost_label  rate_5_pc  rate_4_pc  rate_3_pc  rate_2_pc  rate_1_pc  \
# 1    Install    56.1798   12.92130    8.42697   5.056180   17.41570
# 2    Install    67.1141   11.40940    7.38255   3.355700   10.73830
# 3    Install    74.0741    8.14815    5.18518   2.962960    9.62963
# 4    Install    85.4701    5.98291    2.56410   0.854701    5.12821
# 5    Install    62.8931    9.43396    6.28931   4.402520   16.98110
#
#      updated  size      installs current_version requires_android  \
# 1 2020-04-16   41M   10,000,000+            1.14       4.4 and up
# 2 2019-05-14   19M   10,000,000+             1.5       4.0 and up
# 3 2020-03-25   42M   50,000,000+         1.18.23       4.1 and up
# 4 2020-04-15  142M  100,000,000+           2.5.1       4.1 and up
# 5 2020-03-25   60M   10,000,000+         1.2.369       4.1 and up
#
#   content_rating                in_app_products          offered_by    year
# 1   Rated for 3+               ₫92,000 per item              VOODOO  2020.0
# 2   Rated for 7+  ₫42,000 - ₫2,100,000 per item  Doodle Mobile Ltd.  2019.0
# 3   Rated for 7+    ₫18,000 - ₫192,000 per item      Level Eight AB  2020.0
# 4  Rated for 12+   ₫6,000 - ₫1,149,999 per item               NEKKI  2020.0
# 5  Rated for 12+  ₫23,000 - ₫1,200,000 per item         Top Actions  2020.0

# %%
## which app has highest installs 
df.groupby('app_name').installs.max().sort_values(ascending=False)
# Out:
# app_name
# Netflix                                               500,000,000+
# Hill Climb Racing                                     500,000,000+
# Dropbox: Cloud Storage to Backup, Sync, File Share    500,000,000+
# Truecaller: Caller ID, spam blocking & call record    500,000,000+
# Adobe Acrobat Reader: PDF Viewer, Editor & Creator    500,000,000+
#                                                           ...
# SyncCal - Exchange to Google                                1,000+
# Dynawrite                                                   1,000+
# Wort Raten                                                  1,000+
# Radio Cuba: free Cuban FM radio live                        1,000+
# Sudoku Zenkai                                               1,000+
# Name: installs, Length: 20305, dtype: object

# %%
netflix=df[df['app_name']=='Netflix']
netflix
# Out:
#      app_name          genre  rating          reviews cost_label  rate_5_pc  \
# 2324  Netflix  Entertainment     4.5  8,512,882 total    Install    78.7402
#
#       rate_4_pc  rate_3_pc  rate_2_pc  rate_1_pc    updated size  \
# 2324    10.2362    3.14961     1.5748    6.29921 2020-04-16  12M
#
#           installs        current_version requires_android content_rating  \
# 2324  500,000,000+  7.52.0 build 19 34798       5.0 and up  Rated for 12+
#
#                    in_app_products     offered_by    year
# 2324  ₫178,137 - ₫272,000 per item  Netflix, Inc.  2020.0

# %%
## which app's overall rating is low and high
df.groupby('app_name').rating.mean().sort_values(ascending=False)
# Out:
# app_name
# Cover Shooting Strike : New Paintball Games         5.0
# Schools Athletics                                   5.0
# Bottle Cap Challenge                                5.0
# Kick King                                           5.0
# Puzzle GameBox (classic puzzles In One App)         5.0
#                                                    ...
# Bgcupid                                             1.6
# Pittsburgh Healthy Ride                             1.6
# BBC Music Magazine - Classical Interviews & News    1.5
# Tingles ASMR - Relaxing & Soothing Sleep Sounds     1.3
# Spatula: TFT Cheat Sheet                            1.1
# Name: rating, Length: 20305, dtype: float64

# %%
df.genre.unique()
# Out:
# array(['Action', 'Puzzle', 'Art & Design', 'Weather', 'Strategy',
#        'Sports', 'Arcade', 'Tools', 'Dating', 'Simulation', 'Racing',
#        'Events', 'Casual', 'Role Playing', 'Adventure', 'Card', 'Casino',
#        'Lifestyle', 'Entertainment', 'Music', 'House & Home',
#        'Food & Drink', 'Auto & Vehicles', 'Health & Fitness',
#        'Communication', 'Productivity', 'Finance', 'Photography',
#        'Books & Reference', 'Board', 'Education', 'Music & Audio',
#        'Beauty', 'Video Players & Editors', 'Educational',
#        'Personalization', 'Business', 'Social', 'Travel & Local', 'Word',
#        'Comics', 'Trivia', 'Shopping', 'News & Magazines',
#        'Maps & Navigation', 'Medical', 'Parenting', 'Libraries & Demo'],
#       dtype=object)

# %%
## within  genre which app has highest and lowest rating

# %%
df.groupby('genre')['app_name', 'rating'].min()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_11004/931021225.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('genre')['app_name', 'rating'].min()
#                                                                   app_name  \
# genre
# Action                                                       4Force Online
# Adventure                                               1% Survival Escape
# Arcade                                                                1942
# Art & Design                 Ad Maker, Video Editor, Explainer Video Maker
# Auto & Vehicles                                         AGAMA Car Launcher
# Beauty                   Abs Workout - Lose Weight in 30 Days. Fitness ...
# Board                                                 101 Yüzbir Okey Elit
# Books & Reference                                 24symbols – online books
# Business                                          1C:Small Business Mobile
# Card                                             "Джокер" – карточная игра
# Casino                           777 Slots™ Huge Win Slots - Classic Slots
# Casual                                                 10 Billion Husbands
# Comics                                      2000 AD Comics and Judge Dredd
# Communication             2nd phone number - free private call and texting
# Dating                                 123 Date Me. Dating and Chat Online
# Education                   1 Video Everyday - 영화, 팝송, 뉴스로 영어공부, 영어 리스닝 연습
# Educational                                                 8 Words Search
# Entertainment                                 19LIVE - play game with Idol
# Events                                   Birthdays & Other Events Reminder
# Finance                                         10bii Financial Calculator
# Food & Drink                                            15 Minutes Recipes
# Health & Fitness                                                  100 Dips
# House & Home                                3D Floor Plan | smart3Dplanner
# Libraries & Demo         Al Quran Pro - Read Quran Offline, MP3 Quran Full
# Lifestyle                              1Muslim - Prayer times, Azan, Qibla
# Maps & Navigation                                         7 Ways Navigator
# Medical                                            A Manual of Acupuncture
# Music                                  AVATAR MUSIK - Music and Dance Game
# Music & Audio             2player 3.0 (Trial Version) Network Media Player
# News & Magazines                                  24h News for Man. United
# Parenting                  Ahgoo Baby Monitor - audio and video monitoring
# Personalization                3D Launcher - Your Perfect 3D Live Launcher
# Photography                                      1998 Cam - Vintage Camera
# Productivity                        10BA Professional Financial Calculator
# Puzzle                                                                 "L"
# Racing                                                              #DRIVE
# Role Playing                                                     #SelfCare
# Shopping                                      BUMP - Buy & Sell Streetwear
# Simulation                                      100 DAYS - Zombie Survival
# Social                                   2Face - 2 Accounts for 2 whatsapp
# Sports                                              10 Pin Shuffle Bowling
# Strategy                       1941 Frozen Front - a WW2 Strategy War Game
# Tools                             1001 TVs--Streaming and Screen Mirroring
# Travel & Local                    1 Currency - Money Converter plus widget
# Trivia                                                101 Pics: Photo Quiz
# Video Players & Editors  2DM : Two Different Movies (One Screen Two Mov...
# Weather                  1Weather: Weather Forecast, News, Radar & Widgets
# Word                                           1 Clue: Words and Syllables
#
#                          rating
# genre
# Action                      1.8
# Adventure                   2.8
# Arcade                      2.3
# Art & Design                2.8
# Auto & Vehicles             3.2
# Beauty                      2.5
# Board                       2.5
# Books & Reference           2.1
# Business                    2.2
# Card                        2.1
# Casino                      3.1
# Casual                      2.5
# Comics                      2.5
# Communication               2.6
# Dating                      2.3
# Education                   1.6
# Educational                 2.8
# Entertainment               1.8
# Events                      3.4
# Finance                     2.5
# Food & Drink                2.6
# Health & Fitness            1.8
# House & Home                2.8
# Libraries & Demo            3.4
# Lifestyle                   1.3
# Maps & Navigation           1.6
# Medical                     2.7
# Music                       3.2
# Music & Audio               2.4
# News & Magazines            1.5
# Parenting                   3.2
# Personalization             2.7
# Photography                 1.6
# Productivity                1.6
# Puzzle                      2.1
# Racing                      2.9
# Role Playing                2.7
# Shopping                    3.2
# Simulation                  1.9
# Social                      1.6
# Sports                      2.2
# Strategy                    2.3
# Tools                       1.1
# Travel & Local              2.9
# Trivia                      2.6
# Video Players & Editors     2.3
# Weather                     2.6
# Word                        3.1

# %%
df.groupby('genre')['app_name', 'rating'].max()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_11004/3045429605.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('genre')['app_name', 'rating'].max()
#                                                                   app_name  \
# genre
# Action                                                       🐓Chicken Gun🐓
# Adventure                                                💡The Office Quest
# Arcade                                                      😁 Dead Defence
# Art & Design                                                  ibis Paint X
# Auto & Vehicles          Проверка авто по базе ГИБДД, VIN, ДТП: Антипер...
# Beauty                   Photo Editor - Photo art & Photo Lab - Art Fil...
# Board                            🐍 Snakes and Ladders - Free Board Games 🎲
# Books & Reference                                    🌼 Japanese Dictionary
# Business                 🏠 Работа на дому / Фриланс / Подработка: ALOT.PRO
# Card                                                                섹시스타맞고
# Casino                                        麻雀 神來也麻雀 (Hong Kong Mahjong)
# Casual                                             💍👗Wedding Dress Maker 2
# Comics                                            火熱漫畫——海量熱門漫畫在線閱讀小說動漫每日更新
# Communication                                     세이클럽 미니 - 대화, 무료채팅, 친구찾기
# Dating                                                      速約 - 免費約會交友App
# Education                                                   🚦 Crossroads 🚦
# Educational                                   Сhess - tactics and strategy
# Entertainment            🎨Relax Color: Antistress coloring book for adults
# Events                                                       八字算命-2020生肖運勢
# Finance                                 فروشا : مدیریت آسان فاکتور و مشتری
# Food & Drink                                                   愛料理 - 美食自己做
# Health & Fitness         🥙Scan Halal food: Additive haram &e-Number Muslim
# House & Home                                                     idealista
# Libraries & Demo                                       ProDex - Gen 1 to 8
# Lifestyle                  🕋 SALAT : Prayer Time , Azan or Du’a (Muslim) 🕌
# Maps & Navigation                                   🗺️ Compass Travel Free
# Medical                                      Справочник заболеваний (Free)
# Music                                                                 АПОЖ
# Music & Audio                                  🎵 Slovak and Czech radios 🎵
# News & Magazines                🚨 Earthquake Network Pro - Realtime alerts
# Parenting                                              Дневник малыша: сон
# Personalization                         💗 Love Wallpapers - 4K Backgrounds
# Photography                  💖 Photo Editor - Pic Editor - Pic Editor Free
# Productivity              🔥Exporter for Facebook - Backup,Print,Export PDF
# Puzzle                                            🔍 Exceptions 1000 Levels
# Racing                    🚔 Robber Race Escape 🚔 Police Car Gangster Chase
# Role Playing                👗👒Garden & Dressup - Flower Princess Fairytale
# Shopping                                          السوق المفتوح - OpenSooq
# Simulation                 🤘 Broworld 🤘 - A Douchebag Adventure Simulation
# Social                                                             来玩-德州扑克
# Sports                                         🏒Puppet Hockey: Pond Head 🏆
# Strategy                                                         🔥 Emporea
# Tools                                                        麥玲玲2020鼠年生肖運程
# Travel & Local            🚀 TRIPA: Trip Itinerary Planner & Travel Expense
# Trivia                                                😈 Doodle Devil Blitz
# Video Players & Editors    🔥Efectum – Slow Motion, Reverse Cam, Fast Video
# Weather                                           🌈Weather Live Wallpapers
# Word                                                            流言侦探-活着的死者
#
#                          rating
# genre
# Action                      5.0
# Adventure                   4.8
# Arcade                      5.0
# Art & Design                4.8
# Auto & Vehicles             4.8
# Beauty                      4.7
# Board                       5.0
# Books & Reference           4.9
# Business                    5.0
# Card                        5.0
# Casino                      4.8
# Casual                      5.0
# Comics                      5.0
# Communication               4.7
# Dating                      5.0
# Education                   5.0
# Educational                 4.9
# Entertainment               4.9
# Events                      4.6
# Finance                     5.0
# Food & Drink                4.9
# Health & Fitness            5.0
# House & Home                5.0
# Libraries & Demo            4.8
# Lifestyle                   5.0
# Maps & Navigation           4.9
# Medical                     5.0
# Music                       5.0
# Music & Audio               4.9
# News & Magazines            5.0
# Parenting                   4.9
# Personalization             5.0
# Photography                 4.9
# Productivity                5.0
# Puzzle                      5.0
# Racing                      4.6
# Role Playing                5.0
# Shopping                    4.8
# Simulation                  5.0
# Social                      5.0
# Sports                      5.0
# Strategy                    5.0
# Tools                       5.0
# Travel & Local              5.0
# Trivia                      4.8
# Video Players & Editors     4.9
# Weather                     4.8
# Word                        5.0

# %%
df.groupby('genre')['app_name', 'rating'].mean()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_11004/4152808152.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('genre')['app_name', 'rating'].mean()
#                            rating
# genre
# Action                   4.140636
# Adventure                4.210110
# Arcade                   4.213692
# Art & Design             4.282418
# Auto & Vehicles          4.348000
# Beauty                   4.185000
# Board                    4.204737
# Books & Reference        4.367748
# Business                 4.242570
# Card                     4.286389
# Casino                   4.327434
# Casual                   4.248685
# Comics                   4.220313
# Communication            4.114925
# Dating                   3.872603
# Education                4.400370
# Educational              4.321277
# Entertainment            4.119849
# Events                   4.285714
# Finance                  4.335196
# Food & Drink             4.374214
# Health & Fitness         4.325871
# House & Home             4.086486
# Libraries & Demo         4.350000
# Lifestyle                4.223574
# Maps & Navigation        4.174691
# Medical                  4.223770
# Music                    4.173109
# Music & Audio            4.324426
# News & Magazines         4.020556
# Parenting                4.363636
# Personalization          4.312752
# Photography              4.246804
# Productivity             4.218260
# Puzzle                   4.333954
# Racing                   4.163772
# Role Playing             4.144949
# Shopping                 4.310909
# Simulation               4.133111
# Social                   4.045886
# Sports                   4.175083
# Strategy                 4.116570
# Tools                    4.233333
# Travel & Local           4.299213
# Trivia                   4.212782
# Video Players & Editors  4.137327
# Weather                  4.287413
# Word                     4.437389

# %%
## which app has large app size
df.groupby('app_name')['size'].max().sort_values()
# Out:
# app_name
# Profit! - Deposit Calculator                                        1.0M
# LRC Editor                                                          1.0M
# Snake WiFi                                                          1.0M
# Wolkenkratzer                                                       1.1M
# Odlotowe Wieżowce                                                   1.1M
#                                                              ...
# Total Domination - Reborn                             Varies with device
# Microsoft Excel: View, Edit, & Create Spreadsheets    Varies with device
# Cat Evolution Clicker                                 Varies with device
# ScytheKick: Scythe Companion                          Varies with device
# Korean Recipes                                        Varies with device
# Name: size, Length: 20305, dtype: object

# %%
## Genre wise app size
df.groupby('genre')['app_name', 'size'].max()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_11004/1761860468.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('genre')['app_name', 'size'].max()
#                                                                   app_name  \
# genre
# Action                                                       🐓Chicken Gun🐓
# Adventure                                                💡The Office Quest
# Arcade                                                      😁 Dead Defence
# Art & Design                                                  ibis Paint X
# Auto & Vehicles          Проверка авто по базе ГИБДД, VIN, ДТП: Антипер...
# Beauty                   Photo Editor - Photo art & Photo Lab - Art Fil...
# Board                            🐍 Snakes and Ladders - Free Board Games 🎲
# Books & Reference                                    🌼 Japanese Dictionary
# Business                 🏠 Работа на дому / Фриланс / Подработка: ALOT.PRO
# Card                                                                섹시스타맞고
# Casino                                        麻雀 神來也麻雀 (Hong Kong Mahjong)
# Casual                                             💍👗Wedding Dress Maker 2
# Comics                                            火熱漫畫——海量熱門漫畫在線閱讀小說動漫每日更新
# Communication                                     세이클럽 미니 - 대화, 무료채팅, 친구찾기
# Dating                                                      速約 - 免費約會交友App
# Education                                                   🚦 Crossroads 🚦
# Educational                                   Сhess - tactics and strategy
# Entertainment            🎨Relax Color: Antistress coloring book for adults
# Events                                                       八字算命-2020生肖運勢
# Finance                                 فروشا : مدیریت آسان فاکتور و مشتری
# Food & Drink                                                   愛料理 - 美食自己做
# Health & Fitness         🥙Scan Halal food: Additive haram &e-Number Muslim
# House & Home                                                     idealista
# Libraries & Demo                                       ProDex - Gen 1 to 8
# Lifestyle                  🕋 SALAT : Prayer Time , Azan or Du’a (Muslim) 🕌
# Maps & Navigation                                   🗺️ Compass Travel Free
# Medical                                      Справочник заболеваний (Free)
# Music                                                                 АПОЖ
# Music & Audio                                  🎵 Slovak and Czech radios 🎵
# News & Magazines                🚨 Earthquake Network Pro - Realtime alerts
# Parenting                                              Дневник малыша: сон
# Personalization                         💗 Love Wallpapers - 4K Backgrounds
# Photography                  💖 Photo Editor - Pic Editor - Pic Editor Free
# Productivity              🔥Exporter for Facebook - Backup,Print,Export PDF
# Puzzle                                            🔍 Exceptions 1000 Levels
# Racing                    🚔 Robber Race Escape 🚔 Police Car Gangster Chase
# Role Playing                👗👒Garden & Dressup - Flower Princess Fairytale
# Shopping                                          السوق المفتوح - OpenSooq
# Simulation                 🤘 Broworld 🤘 - A Douchebag Adventure Simulation
# Social                                                             来玩-德州扑克
# Sports                                         🏒Puppet Hockey: Pond Head 🏆
# Strategy                                                         🔥 Emporea
# Tools                                                        麥玲玲2020鼠年生肖運程
# Travel & Local            🚀 TRIPA: Trip Itinerary Planner & Travel Expense
# Trivia                                                😈 Doodle Devil Blitz
# Video Players & Editors    🔥Efectum – Slow Motion, Reverse Cam, Fast Video
# Weather                                           🌈Weather Live Wallpapers
# Word                                                            流言侦探-活着的死者
#
#                                        size
# genre
# Action                   Varies with device
# Adventure                Varies with device
# Arcade                   Varies with device
# Art & Design             Varies with device
# Auto & Vehicles          Varies with device
# Beauty                                  82M
# Board                    Varies with device
# Books & Reference        Varies with device
# Business                 Varies with device
# Card                     Varies with device
# Casino                   Varies with device
# Casual                   Varies with device
# Comics                   Varies with device
# Communication            Varies with device
# Dating                   Varies with device
# Education                Varies with device
# Educational              Varies with device
# Entertainment            Varies with device
# Events                                 7.5M
# Finance                  Varies with device
# Food & Drink             Varies with device
# Health & Fitness         Varies with device
# House & Home             Varies with device
# Libraries & Demo         Varies with device
# Lifestyle                Varies with device
# Maps & Navigation        Varies with device
# Medical                  Varies with device
# Music                    Varies with device
# Music & Audio            Varies with device
# News & Magazines         Varies with device
# Parenting                Varies with device
# Personalization          Varies with device
# Photography              Varies with device
# Productivity             Varies with device
# Puzzle                   Varies with device
# Racing                   Varies with device
# Role Playing             Varies with device
# Shopping                 Varies with device
# Simulation               Varies with device
# Social                   Varies with device
# Sports                   Varies with device
# Strategy                 Varies with device
# Tools                    Varies with device
# Travel & Local           Varies with device
# Trivia                   Varies with device
# Video Players & Editors  Varies with device
# Weather                  Varies with device
# Word                     Varies with device

# %%
df.groupby('genre')['app_name', 'size'].min()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_11004/3065093024.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('genre')['app_name', 'size'].min()
#                                                                   app_name  \
# genre
# Action                                                       4Force Online
# Adventure                                               1% Survival Escape
# Arcade                                                                1942
# Art & Design                 Ad Maker, Video Editor, Explainer Video Maker
# Auto & Vehicles                                         AGAMA Car Launcher
# Beauty                   Abs Workout - Lose Weight in 30 Days. Fitness ...
# Board                                                 101 Yüzbir Okey Elit
# Books & Reference                                 24symbols – online books
# Business                                          1C:Small Business Mobile
# Card                                             "Джокер" – карточная игра
# Casino                           777 Slots™ Huge Win Slots - Classic Slots
# Casual                                                 10 Billion Husbands
# Comics                                      2000 AD Comics and Judge Dredd
# Communication             2nd phone number - free private call and texting
# Dating                                 123 Date Me. Dating and Chat Online
# Education                   1 Video Everyday - 영화, 팝송, 뉴스로 영어공부, 영어 리스닝 연습
# Educational                                                 8 Words Search
# Entertainment                                 19LIVE - play game with Idol
# Events                                   Birthdays & Other Events Reminder
# Finance                                         10bii Financial Calculator
# Food & Drink                                            15 Minutes Recipes
# Health & Fitness                                                  100 Dips
# House & Home                                3D Floor Plan | smart3Dplanner
# Libraries & Demo         Al Quran Pro - Read Quran Offline, MP3 Quran Full
# Lifestyle                              1Muslim - Prayer times, Azan, Qibla
# Maps & Navigation                                         7 Ways Navigator
# Medical                                            A Manual of Acupuncture
# Music                                  AVATAR MUSIK - Music and Dance Game
# Music & Audio             2player 3.0 (Trial Version) Network Media Player
# News & Magazines                                  24h News for Man. United
# Parenting                  Ahgoo Baby Monitor - audio and video monitoring
# Personalization                3D Launcher - Your Perfect 3D Live Launcher
# Photography                                      1998 Cam - Vintage Camera
# Productivity                        10BA Professional Financial Calculator
# Puzzle                                                                 "L"
# Racing                                                              #DRIVE
# Role Playing                                                     #SelfCare
# Shopping                                      BUMP - Buy & Sell Streetwear
# Simulation                                      100 DAYS - Zombie Survival
# Social                                   2Face - 2 Accounts for 2 whatsapp
# Sports                                              10 Pin Shuffle Bowling
# Strategy                       1941 Frozen Front - a WW2 Strategy War Game
# Tools                             1001 TVs--Streaming and Screen Mirroring
# Travel & Local                    1 Currency - Money Converter plus widget
# Trivia                                                101 Pics: Photo Quiz
# Video Players & Editors  2DM : Two Different Movies (One Screen Two Mov...
# Weather                  1Weather: Weather Forecast, News, Radar & Widgets
# Word                                           1 Clue: Words and Syllables
#
#                           size
# genre
# Action                    100M
# Adventure                 100M
# Arcade                    1.0M
# Art & Design               10M
# Auto & Vehicles            10M
# Beauty                     15M
# Board                     102M
# Books & Reference        10.0M
# Business                  1.2M
# Card                      1.8M
# Casino                    100M
# Casual                   10.0M
# Comics                     10M
# Communication             1.6M
# Dating                    1.5M
# Education                 1.1M
# Educational                10M
# Entertainment             1.2M
# Events                     12M
# Finance                   1.0M
# Food & Drink               10M
# Health & Fitness          1.3M
# House & Home               12M
# Libraries & Demo          3.6M
# Lifestyle                 1.9M
# Maps & Navigation         1.5M
# Medical                   1.8M
# Music                     100M
# Music & Audio             1.0M
# News & Magazines           10M
# Parenting                  10M
# Personalization           1.2M
# Photography               1.1M
# Productivity              1.1M
# Puzzle                    1.2M
# Racing                    100M
# Role Playing              1.7M
# Shopping                   11M
# Simulation                100M
# Social                    1.8M
# Sports                    1.4M
# Strategy                  1.1M
# Tools                     1.2M
# Travel & Local             10M
# Trivia                    100M
# Video Players & Editors   1.1M
# Weather                   1.4M
# Word                      1.7M

# %%
## unique app development company
df.offered_by.nunique()
# Out:
# 9319

# %%
## which company has more apps on play store
df.offered_by.value_counts()
# Out:
# mobirix                  83
# Tapps Games              72
# VOODOO                   47
# BitMango                 46
# Gameloft SE              41
#                          ..
# VeBest                    1
# Martin Florek             1
# Smart Applications YE     1
# orangemonkie team         1
# Chois & Co.               1
# Name: offered_by, Length: 9319, dtype: int64

# %%
df.groupby('genre').offered_by.value_counts().sort_values()
# Out:
# genre            offered_by
# Music & Audio    Paolo Valerdi               1
# Productivity     Ultimate Mobile             1
#                  Uncaught Exception Inc.     1
#                  UniqTec Inc.                1
#                  Unstatic Ltd Co             1
#                                             ..
# Food & Drink     DIL                        29
# Music & Audio    Radioworld FM              30
# Personalization  thema                      31
# Puzzle           BitMango                   36
# Casual           Tapps Games                40
# Name: offered_by, Length: 12877, dtype: int64

# %%
## apps offered by mobirisk
mobirix=df[df['offered_by']=='mobirix']
mobirix
# Out:
#                           app_name     genre  rating          reviews  \
# 259             Tower Defense King  Strategy     4.3    128,539 total
# 274            Jigsaw Puzzle World    Puzzle     4.3     90,794 total
# 430                   Fishing Hook    Sports     4.4  1,537,041 total
# 435               Hit & Knock down    Sports     4.3    361,071 total
# 465            World Soccer League    Sports     4.2  1,530,564 total
# ...                            ...       ...     ...              ...
# 39825           Moving Ball Puzzle    Puzzle     4.3     25,540 total
# 43359  Pro Billiards 3balls 4balls    Sports     4.2        430 total
# 43808                 Pinball King    Arcade     4.2     46,411 total
# 43817             Color Ball Blast    Arcade     4.4      2,460 total
# 47021               Marble Mission    Puzzle     4.3     74,089 total
#
#       cost_label  rate_5_pc  rate_4_pc  rate_3_pc  rate_2_pc  rate_1_pc  \
# 259      Install    66.2252    15.8940    8.60927    2.64901    6.62252
# 274      Install    66.2252    17.8808    8.60927    1.98676    5.29801
# 430      Install    69.4444    14.5833    8.33333    2.08333    5.55556
# 435      Install    67.5676    15.5405    8.78378    2.70270    5.40541
# 465      Install    68.4931    10.2740    6.84932    3.42466   10.95890
# ...          ...        ...        ...        ...        ...        ...
# 39825    Install    68.4931    12.3288    8.21918    2.73973    8.21918
# 43359    Install    55.8659    29.0503    7.82123    1.67598    5.58659
# 43808    Install    57.1429    21.1429   12.00000    3.42857    6.28571
# 43817    Install    74.0741    10.3704    7.40741    2.96296    5.18518
# 47021    Install    65.3595    16.9935    9.15033    2.61438    5.88235
#
#          updated size      installs current_version requires_android  \
# 259   2019-12-19  44M    5,000,000+           1.4.5       4.1 and up
# 274   2020-01-06  22M   10,000,000+      2020.01.06       4.1 and up
# 430   2020-04-16  54M   50,000,000+           2.3.2       4.1 and up
# 435   2020-03-12  63M   10,000,000+           1.3.3       4.1 and up
# 465   2020-03-16  46M  100,000,000+         1.9.9.4       4.0 and up
# ...          ...  ...           ...             ...              ...
# 39825 2020-04-03  14M    5,000,000+            1.23       4.1 and up
# 43359 2020-04-02  49M       10,000+           1.0.6       4.4 and up
# 43808 2019-11-27  54M    5,000,000+           1.3.3       4.1 and up
# 43817 2020-03-09  33M      100,000+           1.4.0       4.1 and up
# 47021 2020-04-03  45M   10,000,000+           1.3.8       4.1 and up
#
#       content_rating                 in_app_products offered_by    year
# 259     Rated for 3+   ₫66,000 - ₫2,200,000 per item    mobirix  2019.0
# 274     Rated for 3+     ₫44,000 - ₫663,000 per item    mobirix  2020.0
# 430     Rated for 3+   ₫44,000 - ₫2,200,000 per item    mobirix  2020.0
# 435     Rated for 3+   ₫66,000 - ₫2,200,000 per item    mobirix  2020.0
# 465     Rated for 7+     ₫44,000 - ₫125,000 per item    mobirix  2020.0
# ...              ...                             ...        ...     ...
# 39825   Rated for 3+  ₫111,000 - ₫1,100,000 per item    mobirix  2020.0
# 43359   Rated for 3+   ₫66,000 - ₫2,200,000 per item    mobirix  2020.0
# 43808   Rated for 3+   ₫66,000 - ₫2,200,000 per item    mobirix  2019.0
# 43817   Rated for 3+      ₫19,000 - ₫87,000 per item    mobirix  2020.0
# 47021   Rated for 3+   ₫66,000 - ₫2,200,000 per item    mobirix  2020.0
#
# [83 rows x 19 columns]

# %%
## category of apps on play store by mobirix
mobirix.groupby('offered_by')['genre'].value_counts().sort_values()
# Out:
# offered_by  genre
# mobirix     Board             1
#             Entertainment     1
#             Racing            2
#             Simulation        2
#             Role Playing      5
#             Strategy          6
#             Action            7
#             Arcade           18
#             Sports           19
#             Puzzle           22
# Name: genre, dtype: int64

# %%
mobirix.genre.value_counts().index
# Out:
# Index(['Puzzle', 'Sports', 'Arcade', 'Action', 'Strategy', 'Role Playing',
#        'Simulation', 'Racing', 'Board', 'Entertainment'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='genre', data=mobirix, palette='hot',
              order=mobirix.genre.value_counts().index);

# %%
## Groupby the apps wrt content_rating
df.content_rating.value_counts()
# Out:
# Rated for 3+     15018
# Rated for 12+     3128
# Rated for 7+      1517
# Rated for 16+      474
# Rated for 18+      410
# Name: content_rating, dtype: int64

# %%
df.content_rating.value_counts().index
# Out:
# Index(['Rated for 3+', 'Rated for 12+', 'Rated for 7+', 'Rated for 16+',
#        'Rated for 18+'],
#       dtype='object')

# %%
sns.countplot(x='content_rating', data=df,
              order=df.content_rating.value_counts().index)
plt.xticks(rotation=90);

# %%
## genre and content rating
df.groupby('genre').content_rating.value_counts()
# Out:
# genre    content_rating
# Action   Rated for 12+     314
#          Rated for 7+      307
#          Rated for 3+      275
#          Rated for 16+     170
#          Rated for 18+      34
#                           ...
# Weather  Rated for 16+       1
# Word     Rated for 3+      422
#          Rated for 12+      23
#          Rated for 7+        5
#          Rated for 16+       2
# Name: content_rating, Length: 161, dtype: int64

# %%
df.groupby('genre')['rate_5_pc','rate_4_pc','rate_3_pc','rate_2_pc','rate_1_pc'].mean()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_11004/3474839891.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('genre')['rate_5_pc','rate_4_pc','rate_3_pc','rate_2_pc','rate_1_pc'].mean()
#                          rate_5_pc  rate_4_pc  rate_3_pc  rate_2_pc  rate_1_pc
# genre
# Action                   66.271661  11.415371   6.814353   3.353282  12.145338
# Adventure                67.343639  12.352637   6.828661   3.313952  10.161115
# Arcade                   68.024332  11.632251   6.824915   3.219967  10.298539
# Art & Design             69.608224  12.979743   5.600080   2.412138   9.399816
# Auto & Vehicles          72.564542  11.867381   4.906429   2.288704   8.372956
# Beauty                   67.102610  12.938171   5.064290   2.629992  12.264922
# Board                    67.565737  12.520571   6.060125   2.969468  10.884108
# Books & Reference        72.529916  12.586362   4.880950   2.049035   7.953742
# Business                 69.179873  12.325760   5.469820   2.432129  10.592424
# Card                     69.679779  13.072479   5.486956   2.399207   9.361583
# Casino                   73.283461   9.989452   5.313970   1.967142   9.445980
# Casual                   68.834739  11.837617   6.768151   3.108060   9.451439
# Comics                   71.815008   8.345018   4.704805   2.987244  12.147929
# Communication            66.039400  11.423040   6.095283   2.959070  13.483209
# Dating                   63.080840   7.723874   5.231906   3.086705  20.876680
# Education                72.635706  13.667003   4.734170   2.092027   6.871100
# Educational              71.441657  11.326036   6.304811   2.315701   8.611800
# Entertainment            67.298541  10.266003   5.683764   3.245626  13.506074
# Events                   69.767936  13.446511   5.569148   1.451225   9.765193
# Finance                  68.782309  16.064998   5.153735   2.603180   7.395784
# Food & Drink             71.178081  14.342889   5.138028   2.401850   6.939155
# Health & Fitness         70.937139  13.295994   4.634543   2.527860   8.604468
# House & Home             65.189432  11.164650   5.946077   3.785954  13.913880
# Libraries & Demo         72.671983  10.829868   4.862362   2.996443   8.639367
# Lifestyle                69.685507  10.913094   5.303639   2.781399  11.316364
# Maps & Navigation        65.100052  14.862674   5.893013   3.177137  10.967133
# Medical                  66.246834  15.291629   5.916313   2.522269  10.022959
# Music                    67.611282  11.046036   6.240717   3.347988  11.753979
# Music & Audio            71.053035  12.789799   5.142617   2.388598   8.625957
# News & Magazines         60.498405  15.735810   5.484539   3.880340  14.400906
# Parenting                73.752342  11.118774   4.371543   2.112320   8.645020
# Personalization          70.389877  12.801549   5.708258   2.656392   8.443930
# Photography              70.069400  11.290901   5.267997   2.530023  10.841686
# Productivity             66.725332  14.345089   5.859274   2.914364  10.155949
# Puzzle                   69.345229  14.129247   6.766422   2.788485   6.970624
# Racing                   67.655518  10.688089   6.392501   3.379749  11.884150
# Role Playing             65.484482  12.697706   6.795229   3.266810  11.755779
# Shopping                 69.657569  14.143590   5.368846   2.475477   8.354524
# Simulation               64.983917  12.542944   7.161105   3.705958  11.606082
# Social                   66.165391   9.296814   5.685909   2.958670  15.893223
# Sports                   66.237173  12.951511   6.454719   3.101170  11.255436
# Strategy                 64.121949  13.295361   7.007223   3.473780  12.101695
# Tools                    69.621058  11.573469   5.220193   2.466111  11.119176
# Travel & Local           72.400711  10.366400   4.346925   2.786317  10.099651
# Trivia                   65.415208  14.922578   7.049258   3.286660   9.326303
# Video Players & Editors  68.447791  10.038054   4.899775   2.760746  13.853641
# Weather                  66.661837  16.879037   5.505512   2.734406   8.219209
# Word                     72.874406  14.141034   5.369134   2.076598   5.538833

# %%
## which genre has highest percentage of 5 stars rating
plt.figure(figsize=(12,6))
sns.barplot(x='genre', y='rate_5_pc', data=df)
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Rating perccentage', fontsize=12)
plt.xticks(rotation=90)
plt.title('Percentage of 5 star rating', fontsize=20, fontstyle='italic');

# %%
## which genre has highest percentage of 4 stars rating
plt.figure(figsize=(12,6))
sns.barplot(x='genre', y='rate_4_pc', data=df)
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Rating perccentage', fontsize=12)
plt.xticks(rotation=90)
plt.title('Percentage of 4 star rating', fontsize=20, fontstyle='italic');

# %%
## which genre has highest percentage of 3 stars rating
plt.figure(figsize=(12,6))
sns.barplot(x='genre', y='rate_3_pc', data=df)
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Rating perccentage', fontsize=12)
plt.xticks(rotation=90)
plt.title('Percentage of 3 star rating', fontsize=20, fontstyle='italic');

# %%
## which genre has highest percentage of 2 stars rating
plt.figure(figsize=(12,6))
sns.barplot(x='genre', y='rate_2_pc', data=df)
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Rating perccentage', fontsize=12)
plt.xticks(rotation=90)
plt.title('Percentage of 2 star rating', fontsize=20, fontstyle='italic');

# %%
## which genre has highest percentage of 1 stars rating
plt.figure(figsize=(12,6))
sns.barplot(x='genre', y='rate_1_pc', data=df)
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Rating perccentage', fontsize=12)
plt.xticks(rotation=90)
plt.title('Percentage of 1 star rating', fontsize=20, fontstyle='italic');

# %%
## how many apps are there under each genre
df.genre.value_counts()
# Out:
# Puzzle                     1664
# Action                     1100
# Education                  1082
# Casual                     1027
# Tools                      1017
# Role Playing                990
# Arcade                      986
# Sports                      903
# Simulation                  900
# Strategy                    863
# Health & Fitness            804
# Productivity                701
# Adventure                   544
# Entertainment               529
# Card                        529
# Lifestyle                   526
# Books & Reference           524
# Music & Audio               479
# Word                        452
# Personalization             447
# Photography                 438
# Racing                      403
# Travel & Local              381
# Board                       380
# Social                      316
# Business                    249
# Video Players & Editors     217
# Communication               201
# News & Magazines            180
# Finance                     179
# Maps & Navigation           162
# Food & Drink                159
# Dating                      146
# Weather                     143
# Trivia                      133
# Medical                     122
# Music                       119
# Casino                      113
# Art & Design                 91
# Comics                       64
# Shopping                     55
# Parenting                    55
# Auto & Vehicles              50
# Educational                  47
# House & Home                 37
# Beauty                       20
# Events                       14
# Libraries & Demo              6
# Name: genre, dtype: int64

# %%
df.genre.value_counts().index
# Out:
# Index(['Puzzle', 'Action', 'Education', 'Casual', 'Tools', 'Role Playing',
#        'Arcade', 'Sports', 'Simulation', 'Strategy', 'Health & Fitness',
#        'Productivity', 'Adventure', 'Entertainment', 'Card', 'Lifestyle',
#        'Books & Reference', 'Music & Audio', 'Word', 'Personalization',
#        'Photography', 'Racing', 'Travel & Local', 'Board', 'Social',
#        'Business', 'Video Players & Editors', 'Communication',
#        'News & Magazines', 'Finance', 'Maps & Navigation', 'Food & Drink',
#        'Dating', 'Weather', 'Trivia', 'Medical', 'Music', 'Casino',
#        'Art & Design', 'Comics', 'Shopping', 'Parenting', 'Auto & Vehicles',
#        'Educational', 'House & Home', 'Beauty', 'Events', 'Libraries & Demo'],
#       dtype='object')

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='genre', data=df,
              order=df.genre.value_counts().index)
plt.xticks(rotation=90)
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Total Apps', fontsize=12)
plt.title('Genre wise apps', fontsize=20, fontstyle='italic');

# %%
##Analyse Puzzle apps
puzzle=df[df['genre']=='Puzzle']

# %%
puzzle.head(5)
# Out:
#                            app_name   genre  rating          reviews  \
# 94          Mr Bullet - Spy Puzzles  Puzzle     4.1    528,764 total
# 148                     Rope Puzzle  Puzzle     4.3     18,271 total
# 233  Cut the Rope: Experiments FREE  Puzzle     4.4    538,681 total
# 234       Cut the Rope: Time Travel  Puzzle     4.6  1,094,452 total
# 236                  Cut the Rope 2  Puzzle     4.6  2,265,680 total
#
#     cost_label  rate_5_pc  rate_4_pc  rate_3_pc  rate_2_pc  rate_1_pc  \
# 94     Install    64.5161   12.25810    7.74194   3.870970   11.61290
# 148    Install    72.4638    7.97101    5.79710   4.347830    9.42029
# 233    Install    74.6269    9.70149    5.97015   2.238810    7.46269
# 234    Install    82.6446    9.91736    3.30579   0.826446    3.30579
# 236    Install    81.3008   10.56910    4.06504   0.813008    3.25203
#
#        updated                size      installs current_version  \
# 94  2020-04-07                 40M   50,000,000+             4.8
# 148 2020-03-24                 15M    5,000,000+          1.0.20
# 233 2018-06-27                 37M   50,000,000+           1.9.0
# 234 2019-10-23  Varies with device   50,000,000+          1.10.0
# 236 2020-04-06  Varies with device  100,000,000+          1.24.1
#
#     requires_android content_rating                in_app_products  \
# 94        4.1 and up  Rated for 16+  ₫23,000 - ₫1,150,000 per item
# 148       5.0 and up   Rated for 3+    ₫23,000 - ₫575,000 per item
# 233     4.0.3 and up   Rated for 3+    ₫21,000 - ₫647,923 per item
# 234       4.2 and up   Rated for 3+    ₫21,000 - ₫655,441 per item
# 236       4.2 and up   Rated for 3+  ₫21,000 - ₫1,075,585 per item
#
#          offered_by    year
# 94     Lion Studios  2020.0
# 148  One Tap Studio  2020.0
# 233        ZeptoLab  2018.0
# 234        ZeptoLab  2019.0
# 236        ZeptoLab  2020.0

# %%
puzzle.shape
# Out:
# (1664, 19)

# %%
## overall average rating for puzzle apps
puzzle.rating.mean()
# Out:
# 4.333954326923074

# %%
puzzle.groupby('genre')['rate_5_pc','rate_4_pc','rate_3_pc','rate_2_pc','rate_1_pc'].mean()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_11004/394571289.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   puzzle.groupby('genre')['rate_5_pc','rate_4_pc','rate_3_pc','rate_2_pc','rate_1_pc'].mean()
#         rate_5_pc  rate_4_pc  rate_3_pc  rate_2_pc  rate_1_pc
# genre
# Puzzle  69.345229  14.129247   6.766422   2.788485   6.970624

# %%
## Analyse Action category
action=df[df['genre']=='Action']

# %%
action
# Out:
#                                 app_name   genre  rating           reviews  \
# 1                            Push'em all  Action     3.8     119,679 total
# 2                        Sky Fighters 3D  Action     4.2     196,685 total
# 3                            Robbery Bob  Action     4.3     984,779 total
# 4                         Shadow Fight 2  Action     4.6  12,861,970 total
# 5         Cover Strike - 3D Team Shooter  Action     4.0      43,322 total
# ...                                  ...     ...     ...               ...
# 52578                     Mobfish Hunter  Action     4.2      54,137 total
# 52609                         Santa Dude  Action     3.9      10,622 total
# 52630  Warlock.io : Action Arena Io Game  Action     4.2          16 total
# 52657    Sky Champ: Galaxy Space Shooter  Action     4.6      42,204 total
# 53144                      God of Attack  Action     4.3      24,251 total
#
#       cost_label  rate_5_pc  rate_4_pc  rate_3_pc  rate_2_pc  rate_1_pc  \
# 1        Install    56.1798   12.92130    8.42697   5.056180   17.41570
# 2        Install    67.1141   11.40940    7.38255   3.355700   10.73830
# 3        Install    74.0741    8.14815    5.18518   2.962960    9.62963
# 4        Install    85.4701    5.98291    2.56410   0.854701    5.12821
# 5        Install    62.8931    9.43396    6.28931   4.402520   16.98110
# ...          ...        ...        ...        ...        ...        ...
# 52578    Install    63.2911   17.08860    6.96203   3.797470    8.86076
# 52609    Install    62.5000    8.12500    5.62500   3.750000   20.00000
# 52630    Install    50.2513   31.15580   12.56280   0.000000    6.03015
# 52657    Install    81.3008    8.13008    4.06504   1.626020    4.87805
# 53144    Install    65.3595   16.33990    9.15033   2.614380    6.53595
#
#          updated  size      installs current_version requires_android  \
# 1     2020-04-16   41M   10,000,000+            1.14       4.4 and up
# 2     2019-05-14   19M   10,000,000+             1.5       4.0 and up
# 3     2020-03-25   42M   50,000,000+         1.18.23       4.1 and up
# 4     2020-04-15  142M  100,000,000+           2.5.1       4.1 and up
# 5     2020-03-25   60M   10,000,000+         1.2.369       4.1 and up
# ...          ...   ...           ...             ...              ...
# 52578 2020-02-24   76M    1,000,000+           3.9.4       4.2 and up
# 52609 2018-05-24   19M    1,000,000+          1.1.13       3.0 and up
# 52630 2020-02-03   31M        1,000+             0.8       4.4 and up
# 52657 2020-04-23   54M    5,000,000+           6.2.1       4.1 and up
# 53144 2020-02-20   65M      500,000+           2.2.5       4.1 and up
#
#       content_rating                 in_app_products          offered_by  \
# 1       Rated for 3+                ₫92,000 per item              VOODOO
# 2       Rated for 7+   ₫42,000 - ₫2,100,000 per item  Doodle Mobile Ltd.
# 3       Rated for 7+     ₫18,000 - ₫192,000 per item      Level Eight AB
# 4      Rated for 12+    ₫6,000 - ₫1,149,999 per item               NEKKI
# 5      Rated for 12+   ₫23,000 - ₫1,200,000 per item         Top Actions
# ...              ...                             ...                 ...
# 52578   Rated for 7+   ₫22,000 - ₫1,100,000 per item  Appxplore (iCandy)
# 52609  Rated for 12+     ₫21,000 - ₫520,063 per item             Firezoo
# 52630   Rated for 3+     ₫16,000 - ₫349,000 per item    Homecooked Games
# 52657   Rated for 3+   ₫22,000 - ₫1,100,000 per item         Spirit Bomb
# 53144   Rated for 7+  ₫104,000 - ₫2,100,000 per item           DAERISOFT
#
#          year
# 1      2020.0
# 2      2019.0
# 3      2020.0
# 4      2020.0
# 5      2020.0
# ...       ...
# 52578  2020.0
# 52609  2018.0
# 52630  2020.0
# 52657  2020.0
# 53144  2020.0
#
# [1100 rows x 19 columns]

# %%
##overall average rating of acton apps
action.rating.mean()
# Out:
# 4.140636363636365

# %%
## percentage rating wrt each star
action.groupby('genre')['rate_5_pc','rate_4_pc','rate_3_pc','rate_2_pc','rate_1_pc'].mean()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_11004/997978861.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   action.groupby('genre')['rate_5_pc','rate_4_pc','rate_3_pc','rate_2_pc','rate_1_pc'].mean()
#         rate_5_pc  rate_4_pc  rate_3_pc  rate_2_pc  rate_1_pc
# genre
# Action  66.271661  11.415371   6.814353   3.353282  12.145338

# %%
## app size of the action apps
action.groupby('app_name')['size'].sum()
# Out:
# app_name
# 4Force Online                                             18M
# A Hollow Doorway                                          49M
# A Tag Knight                                              41M
# AWP Mode: Elite online 3D sniper action    Varies with device
# AXES.io                                                   68M
#                                                   ...
# 王牌特攻                                                      38M
# 裁決之刃                                                     5.2M
# 魔剣伝説                                                      94M
# 魔物獵人EXPLORE_MHXR                                         100M
# 🐓Chicken Gun🐓                                             56M
# Name: size, Length: 1100, dtype: object

# %%
## which action app has more installs
action.groupby('app_name').installs.sum().sort_values(ascending=False)
# Out:
# app_name
# Garena Free Fire: Wonderland                500,000,000+
# Temple Run 2                                500,000,000+
# Dead Spreading:Survival                         500,000+
# Sniper Zombies: Offline Game                    500,000+
# Death From Above                                500,000+
#                                                 ...
# Auto Arena - Duel of heroic                       1,000+
# Goblin Wizard                                     1,000+
# Soul Fighting                                     1,000+
# No Gravity Lite - Space Combat Adventure          1,000+
# Lily's battle!                                    1,000+
# Name: installs, Length: 1100, dtype: object

# %%
## freefire
ff=action[action['app_name']=='Garena Free Fire: Wonderland']
ff
# Out:
#                         app_name   genre  rating           reviews cost_label  \
# 52  Garena Free Fire: Wonderland  Action     4.3  46,555,575 total    Install
#
#     rate_5_pc  rate_4_pc  rate_3_pc  rate_2_pc  rate_1_pc    updated size  \
# 52    76.3359    6.87023    3.81679    2.29008     10.687 2020-04-03  41M
#
#         installs current_version requires_android content_rating  \
# 52  500,000,000+          1.47.0     4.0.3 and up  Rated for 12+
#
#                  in_app_products                              offered_by  \
# 52  ₫6,000 - ₫2,550,000 per item  GARENA INTERNATIONAL I PRIVATE LIMITED
#
#       year
# 52  2020.0

# %%
##Temple run
tmp=action[action['app_name']=='Temple Run 2']
tmp
# Out:
#         app_name   genre  rating          reviews cost_label  rate_5_pc  \
# 25  Temple Run 2  Action     4.3  9,083,755 total    Install    71.9424
#
#     rate_4_pc  rate_3_pc  rate_2_pc  rate_1_pc    updated size      installs  \
# 25    10.0719     5.7554     2.8777    9.35252 2020-03-31  88M  500,000,000+
#
#    current_version requires_android content_rating  \
# 25          1.66.0       4.1 and up   Rated for 7+
#
#                   in_app_products      offered_by    year
# 25  ₫23,000 - ₫1,150,000 per item  Imangi Studios  2020.0

# %%
##Analysis on Entertainment
ent=df[df['genre']=='Entertainment']

# %%
ent
# Out:
#                                                 app_name          genre  \
# 422                     iflix - Movies, TV Series & News  Entertainment
# 749                                       Talking Ginger  Entertainment
# 752                                       Talking Angela  Entertainment
# 1398                                           TOYA Live  Entertainment
# 1402                                                MCat  Entertainment
# ...                                                  ...            ...
# 53520   Netboom - 🎮Play PC games on Mobile 🔥Cloud Gaming  Entertainment
# 53582                                   DVR Hub for Xbox  Entertainment
# 53665       Real Terrorist Shooting Games: Gun Shoot War  Entertainment
# 53675  9GAG: Funny gifs, pics, fresh memes & viral vi...  Entertainment
# 53693   Mandala Color by Number Draw Book Page Pixel Art  Entertainment
#
#        rating          reviews cost_label  rate_5_pc  rate_4_pc  rate_3_pc  \
# 422       4.2    532,724 total    Install    64.5161   15.48390    7.74194
# 749       4.0  1,828,203 total    Install    67.1141    7.38255    5.36913
# 752       3.5  1,943,004 total    Install    54.3478    5.97826    5.97826
# 1398      4.4      2,915 total    Install    81.9672    2.45902    4.91803
# 1402      3.9        714 total    Install    56.4972   11.86440   12.99440
# ...       ...              ...        ...        ...        ...        ...
# 53520     3.1     10,312 total    Install    43.8596    7.45614    5.70175
# 53582     4.4     22,690 total    Install    74.0741   13.33330    4.44444
# 53665     4.3        192 total    Install    75.7576    6.81818    1.51515
# 53675     4.6  1,636,211 total    Install    79.3651   14.28570    2.38095
# 53693     3.9         36 total    Install    67.1141    2.68456    2.68456
#
#        rate_2_pc  rate_1_pc    updated                size      installs  \
# 422     3.225810    9.03226 2020-04-16                 24M   50,000,000+
# 749     2.684560   17.44970 2020-01-20  Varies with device  100,000,000+
# 752     3.804350   29.89130 2019-11-04                 49M  100,000,000+
# 1398    0.819672    9.83607 2020-04-13                 20M      500,000+
# 1402    2.824860   15.81920 2020-03-30                 37M      100,000+
# ...          ...        ...        ...                 ...           ...
# 53520   4.385960   38.59650 2020-04-07                 11M    1,000,000+
# 53582   2.222220    5.92593 2020-02-16                 33M      500,000+
# 53665   8.333330    7.57576 2020-01-01                 29M       50,000+
# 53675   0.793651    3.17460 2020-04-28                 16M   10,000,000+
# 53693   5.369130   22.14770 2018-05-14                 26M       10,000+
#
#                 current_version requires_android content_rating  \
# 422                3.45.0-19722       4.3 and up  Rated for 12+
# 749                    2.7.3.18       4.4 and up   Rated for 3+
# 752                     2.9.0.5       4.4 and up   Rated for 7+
# 1398                     1.5.13       5.0 and up  Rated for 12+
# 1402                      1.4.0       4.3 and up  Rated for 12+
# ...                         ...              ...            ...
# 53520                     1.0.9       5.0 and up  Rated for 12+
# 53582                  1.11.220       4.1 and up   Rated for 3+
# 53665                       1.6       5.0 and up  Rated for 12+
# 53675  6.82.01r21586-9e58adc554       5.0 and up  Rated for 12+
# 53693                       1.3       4.1 and up   Rated for 3+
#
#                       in_app_products                          offered_by  \
# 422        ₫6,000 - ₫545,000 per item                       iflix Sdn Bhd
# 749       ₫25,000 - ₫514,000 per item                     Outfit7 Limited
# 752       ₫25,000 - ₫642,000 per item                     Outfit7 Limited
# 1398    ₫23,000 - ₫9,000,000 per item                           toya live
# 1402   ₫136,000 - ₫2,650,000 per item                   VGame Interactive
# ...                               ...                                 ...
# 53520   ₫23,000 - ₫6,950,000 per item  ☆Editor's Choice Cloud Gaming App☆
# 53582                ₫23,000 per item                      Room408 Design
# 53665               ₫178,000 per item                  FPS Shooting Games
# 53675     ₫21,000 - ₫302,000 per item                                9GAG
# 53693     ₫74,000 - ₫226,000 per item                         App Robbers
#
#          year
# 422    2020.0
# 749    2020.0
# 752    2019.0
# 1398   2020.0
# 1402   2020.0
# ...       ...
# 53520  2020.0
# 53582  2020.0
# 53665  2020.0
# 53675  2020.0
# 53693  2018.0
#
# [529 rows x 19 columns]

# %%
##Overall average rating of Entertainment app
ent.rating.mean()
# Out:
# 4.119848771266539

# %%
##Uniques app under entertainment category
ent.app_name.nunique()
# Out:
# 529

# %%
##Whict entertainment app has highest rating
ent.groupby('app_name').rating.max().sort_values(ascending=False)
# Out:
# app_name
# Hiba Nawab                                          4.9
# Birthday Cake Photo Frames Editor 2017              4.9
# DROPOUT by CollegeHumor                             4.9
# The Chosen                                          4.9
# Haya-Entertaining voice chat app                    4.9
#                                                    ...
# Pro Wrestling Illustrated                           2.4
# Skin Packs for Minecraft                            2.3
# 스타플레이 : STARPLAY - KPOP 아이돌 콘텐츠 THE SHOW 더쇼 순위투표    2.3
# Coastiality VR                                      2.2
# Yarn - Chat Fiction                                 1.8
# Name: rating, Length: 529, dtype: float64

# %%
## Which app has installed more
ent.groupby('app_name').installs.max().sort_values(ascending=False)
# Out:
# app_name
# Netflix                                              500,000,000+
# Laser Pointer for Cat Simulator                          500,000+
# Sexopoly 🍑 Couple Sex Games & Truth or Dare              500,000+
# Hype Text - Type Animated Text & Mojo Story Maker        500,000+
# Posteroid                                                500,000+
#                                                          ...
# ZAYNmoji                                                   1,000+
# Viral Videos Daily                                         1,000+
# Weave with iWeaveIt                                        1,000+
# Steins;Gate ALARM                                          1,000+
# MapGenie: Escape From Tarkov Map                           1,000+
# Name: installs, Length: 529, dtype: object

# %%
## entertainment apps falls under which company
ent.offered_by.value_counts()
# Out:
# Color By Number Pixelart Pages - Coloring Arena    8
# Outfit7 Limited                                    7
# escapex Limited                                    6
# Cosmic Mobile Apps                                 6
# Map Genie                                          6
#                                                   ..
# Apalon Apps                                        1
# ColorTime & PuzzleTime                             1
# Coloring Games and Coloring Book for Adults        1
# EYEWIND                                            1
# App Robbers                                        1
# Name: offered_by, Length: 394, dtype: int64

# %%
##Content rated
ent.groupby('content_rating').app_name.value_counts()
# Out:
# content_rating  app_name
# Rated for 12+   2020生肖運勢-靈機妙算姓名算命 靈符許願 點燈祈福 請仙庇佑 化太歲 紫微八字占卜 面相手相      1
#                 40 Психологических Тестов + тесты IQ                  1
#                 90s - Glitch VHS & Vaporwave Video Effects Editor     1
#                 9GAG: Funny gifs, pics, fresh memes & viral videos    1
#                 Akinator                                              1
#                                                                      ..
# Rated for 7+    Nimo TV – Live Game Streaming                         1
#                 Puma Family Sim Online                                1
#                 Smash Dude® - Graffiti                                1
#                 TFT Wiki                                              1
#                 Talking Angela                                        1
# Name: app_name, Length: 529, dtype: int64

# %%
ent.content_rating.value_counts()
# Out:
# Rated for 3+     352
# Rated for 12+    129
# Rated for 16+     24
# Rated for 18+     14
# Rated for 7+      10
# Name: content_rating, dtype: int64

# %%
ent.content_rating.value_counts().index
sns.countplot(x='content_rating', data=ent,
             order=ent.content_rating.value_counts().index)
plt.xticks(rotation=90)
plt.xlabel('Content Rating', fontsize=12)
plt.ylabel('Total apps', fontsize=12)
plt.title('Apps under each content rated', fontsize=20, fontstyle='italic');
